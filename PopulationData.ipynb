# %%
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None

# %%
# The path to our CSV file
file = "population_total_long.csv"

# Read our Kickstarter data into pandas
df = pd.read_csv(file)
df.head()
# Out:
#   Country Name  Year    Count
# 0        Aruba  1960    54211
# 1  Afghanistan  1960  8996973
# 2       Angola  1960  5454933
# 3      Albania  1960  1608800
# 4      Andorra  1960    13411

# %%
df.columns
# Out:
# Index(['Country Name', 'Year', 'Count'], dtype='object')

# %%
dfP = df.pivot(index='Country Name', columns='Year', values = 'Count')
dfP
# Out:
# Year                         1960        1961        1962        1963  \
# Country Name
# Afghanistan             8996973.0   9169410.0   9351441.0   9543205.0
# Albania                 1608800.0   1659800.0   1711319.0   1762621.0
# Algeria                11057863.0  11336339.0  11619828.0  11912803.0
# American Samoa            20123.0     20602.0     21253.0     22034.0
# Andorra                   13411.0     14375.0     15370.0     16412.0
# ...                           ...         ...         ...         ...
# Virgin Islands (U.S.)     32500.0     34300.0     35000.0     39800.0
# West Bank and Gaza            NaN         NaN         NaN         NaN
# Yemen, Rep.             5315355.0   5393036.0   5473671.0   5556766.0
# Zambia                  3070776.0   3164329.0   3260650.0   3360104.0
# Zimbabwe                3776681.0   3905034.0   4039201.0   4178726.0
#
# Year                         1964        1965        1966        1967  \
# Country Name
# ...

# %%
dfP50 = dfP.drop(columns=[1960,1961,1962,1963,1964,1965,1966])
dfP50
# Out:
# Year                         1967        1968        1969        1970  \
# Country Name
# Afghanistan            10399926.0  10637063.0  10893776.0  11173642.0
# Albania                 1965598.0   2022272.0   2081695.0   2135479.0
# Algeria                13275026.0  13663583.0  14061722.0  14464985.0
# American Samoa            25248.0     25989.0     26703.0     27363.0
# Andorra                   20758.0     21890.0     23058.0     24276.0
# ...                           ...         ...         ...         ...
# Virgin Islands (U.S.)     49100.0     55700.0     60300.0     63476.0
# West Bank and Gaza            NaN         NaN         NaN         NaN
# Yemen, Rep.             5907874.0   6001852.0   6097035.0   6193384.0
# Zambia                  3797873.0   3918872.0   4045740.0   4179067.0
# Zimbabwe                4779827.0   4941906.0   5111337.0   5289303.0
#
# Year                         1971        1972        1973        1974  \
# Country Name
# ...
